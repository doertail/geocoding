# %% [markdown]
# # 위도경도 구하기

# %%
pip install geopy

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %% [markdown]
# ### input

# %%
# 여러 줄의 주소 데이터를 입력합니다.
address_data = """

"""

# 개행 문자('\n')를 기준으로 데이터를 분할하여 리스트에 저장합니다.
address_list = address_data.split('\n')

#  # 주소 리스트 출력 (DEBUG)
# for address in address_list:
#     print("(", address, ")", sep='', end =',\n')
# Out:
# 커널을 시작하지 못했습니다.
#
# Jupyter 서버 작동이 중단되었습니다. 연결할 수 없습니다.
#
# Jupyter의 오류 코드: 1
#
# usage: jupyter.py [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#
#                   [--paths] [--json] [--debug]
#
#                   [subcommand]
#
#
#
# Jupyter: Interactive Computing
#
#
#
# positional arguments:
#
#   subcommand     the subcommand to launch
#
#
#
# optional arguments:
#
#   -h, --help     show this help message and exit
#
#   --version      show the versions of core jupyter packages and exit
#
#   --config-dir   show Jupyter config dir
#
#   --data-dir     show Jupyter data dir
#
#   --runtime-dir  show Jupyter runtime dir
#
#   --paths        show all Jupyter paths. Add --json for machine-readable
#
#                  format.
#
#   --json         output paths as machine-readable json
#
#   --debug        output debug information about paths
#
#
#
# Available subcommands: console dejavu events kernel kernelspec lab
#
# ...

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

# 위치:위도, 경도 꼴로 출력
for i in address_list:
  print(i, end=':')
  print(geocoding(i)[0], end=', ')
  print(geocoding(i)[1])
# Out:
# :0, 0
# 서울역:37.5548238, 126.9722165
# 낙성대:37.4770623, 126.9634876
# :0, 0

# %% [markdown]
# ## 위도 경도 구하기 ref:
#
# * https://wonhwa.tistory.com/29
#
# * https://wonhwa1.blogspot.com/2022/10/python-geopy.html

# %% [markdown]
# ## 서울역과의 거리 구하기

# %%
pip install haversine

# %%
### 각 위치의 위도 경도 데이터 입력
data = [(37.57105, 127.06806),
  (37.5820354, 127.0338924),
  (37.6493408, 127.0136861),
  (37.4770623, 126.9634876),
  (37.50101935, 126.89045483434705),
  (35.150761900000006, 129.11657707493106),
  (35.1033486, 129.0269106),
  (35.20917095, 129.08784396642872),
  (35.2514917, 129.0454309),
  (35.150761900000006, 129.11657707493106),
  (35.1029191, 129.0407161),
  (35.150761900000006, 129.11657707493106),
  (35.0463583, 128.9664467477741),
  (35.2514917, 129.0454309),
  (35.1029191, 129.0407161),
  (35.150761900000006, 129.11657707493106),
  (35.8693059, 128.60171031137094),
  (37.577803, 127.037593),
  (35.8661571, 128.639158),
  (35.8297517, 128.6901254233253),
  (35.88373955, 128.5946225865992),
  (35.62063, 127.4656067),
  (35.88373955, 128.5946225865992),
  (37.577803, 127.037593),
  (37.5115881, 127.085571),
  (35.84733345, 128.55881950737506),
  (35.8297517, 128.6901254233253),
  (35.8678431, 128.5966739699789),
  (35.9719216, 128.6982228),
  (35.8296845, 128.6168175),
  (35.86943, 128.5807059),
  (35.8391727, 128.5738617),
  (35.84733345, 128.55881950737506),
  (35.8683, 128.58952),
  (34.7398667, 127.730359),
  (37.4068054, 126.6261064),
  (37.39453685, 126.63085567905577),
  (37.4737356, 126.6215448513303),
  (37.6319717, 126.48464729155313),
  (37.7485241, 126.4859815992089),
  (37.4068054, 126.6261064),
  (37.4737356, 126.6215448513303),
  (37.505711, 126.7212829),
  (37.751355849999996, 126.48511598563105),
  (36.036817299999996, 129.37506896094027),
  (35.37085, 127.1378),
  (35.437278, 126.701335),
  (37.4899318, 126.7556875),
  (35.8500537, 127.1623649),
  (35.8500537, 127.1623649),
  (35.77698, 127.44458),
  (35.6329664, 127.2898846),
  (35.37085, 127.1378),
  (34.802935950000006, 126.35718568234265),
  (34.95491025, 127.481521688465),
  (35.328626650000004, 126.98555931731406),
  (35.2148983, 127.4663475),
  (34.6714882, 126.9336409),
  (34.5081355, 126.804203),
  (34.755939999999995, 126.6297665658206),
  (34.4238414, 126.3468611),
  (34.9266193, 127.51012204423594),
  (34.9266193, 127.51012204423594),
  (35.328626650000004, 126.98555931731406),
  (34.7615255, 127.0927366),
  (34.6714882, 126.9336409),
  (34.5081355, 126.804203),
  (34.4238414, 126.3468611),
  (34.79002, 126.3725059),
  (34.802935950000006, 126.35718568234265),
  (35.312747, 127.4349471),
  (34.6385374, 126.8327221),
  (35.7375176, 128.2713043),
  (36.1053877, 128.7089894),
  (36.7720423, 128.0746545),
  (36.9420814, 128.7366091),
  (35.63218, 128.7182),
  (36.010784799999996, 128.39906413614204),
  (35.1882625, 129.04003207077852),
  (35.8776886, 129.22034209075935),
  (36.0434851, 129.3686129),
  (36.7720423, 128.0746545),
  (36.359464, 129.3815606),
  (35.63218, 128.7182),
  (0, 0),
  (0, 0),
  (0, 0),
  (36.9420814, 128.7366091),
  (33.4799602, 126.4144451),
  (36.144512250000005, 128.37313778696836),
  (36.41994, 129.09199),
  (36.7688095, 128.4524262),
  (0, 0),
  (35.1865248, 128.093164),
  (34.7446531, 127.68002837636234),
  (35.4915738, 128.7551003),
  (35.4302837, 127.8592473),
  (35.1848028, 128.54845047314373),
  (35.1803459, 128.1079953),
  (35.1865248, 128.093164),
  (35.92965, 128.93902),
  (35.158731700000004, 128.70995374734457),
  (35.4915738, 128.7551003),
  (35.4302837, 127.8592473),
  (0, 0),
  (34.825884, 128.4289299),
  (34.8481638, 128.4218734),
  (34.854254, 128.433205),
  (35.2328426, 128.8720995),
  (35.2353831, 128.87571561772756),
  (35.4915738, 128.7551003),
  (35.52993, 128.49609),
  (35.4302837, 127.8592473),
  (33.4905148, 126.5239964),
]

# %%
from haversine import haversine

#### 서울역
seoulStation = (37.5548238, 126.9722165)

for i in data:
    print(haversine(seoulStation, i))
# Out:
# 8.6384198106512
# 6.221265489861741
# 11.126685907657768
# 8.680902005854064
# 9.369037963391488
# 329.1238459048695
# 328.89336045545474
# 322.3116727154711
# 316.2446834584007
# 329.1238459048695
# 329.62652908523995
# 329.1238459048695
# 331.24752866148685
# 316.2446834584007
# 329.62652908523995
# 329.1238459048695
# 237.10841503242108
# 6.303314202897406
# 239.44370108419545
# 245.46148073036937
# 235.44514170206702
# 219.5367329638437
# 235.44514170206702
# 6.303314202897406
# 11.091432080246635
# 236.75307649946083
# 245.46148073036937
# 236.96329726818067
# 233.69860286858815
# 241.44371793081802
# 235.9553186289953
# 238.2868732234601
# 236.75307649946083
# 236.5336970607968
# 320.32245547369564
# 34.69328201800723
# 35.00168977523597
# 32.21673529234202
# 43.80613560078475
# 47.92003185125376
# 34.69328201800723
# 32.21673529234202
# 22.791561571172473
# 48.129537405335384
# 272.50509977158845
# 43.80613560078475
# 267.6742095843603
# 276.6913261619582
# 267.7502192574209
# ...
